# %%
G = DiGraph()

# %%
#Where d is the height of the box, j is the width, and n is the number to fit in the box.
d = 4
j = 4
start = [0,0,0,0]

# %%
# def generate_children(d, j, blocks):
#     children = []
#     if blocks == [0,0,0,0]:
#         return[[1,0,0,0]]
#     for i in range(j - 1):
#         if blocks[i] < j and blocks[i] != 0:
#             children.append(blocks.insert(i, blocks[i] +1 ))
#         elif blocks[i] == 0 and blocks[i - 1] != 0:
#             children.append(blocks.insert(i, blocks[i] +1 ))
# #             print("you should have made it here")
#     return children 
        
    
def generate_children(d, j, blocks):
    children = []
    if blocks == [0, 0, 0, 0]:
        return [[1, 0, 0, 0]]
    for i in range(j - 1):
        if blocks[i] < j and blocks[i] != 0: ##don't include if the i + 1 > i 
            new_blocks = blocks.copy()
            new_blocks[i] += 1
            children.append(new_blocks)
        elif blocks[i] == 0 and blocks[i - 1] != 0:
            new_blocks = blocks.copy()
            new_blocks[i] += 1
            children.append(new_blocks)
            # print("you should have made it here")
    return children

# %%
c = generate_children(d, j, start)
a = generate_children(d, j, c[0])
b = generate_children(d, j, a[1])
print(a, b)
# Out:
# [[2, 0, 0, 0], [1, 1, 0, 0]] [[2, 1, 0, 0], [1, 2, 0, 0], [1, 1, 1, 0]]

# %%
G.add_vertex(tuple(start))
for v in generate_children(d, j, start):
    G.add_edge(tuple(start), tuple(v))


for child in generate_children(d, j, start):
    for v in generate_children(d, j, child):
        G.add_edge(tuple(child), tuple(v))
G.show()
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
g = DiGraph()
blocks = [0,0,0,0]

def add_edges_recursive(graph, blocks, d, j):
    for child in generate_children(d, j, blocks):
        graph.add_edge(tuple(blocks), tuple(child))
        add_edges_recursive(graph, child, d, j)

# %%
add_edges_recursive(g, blocks, d, j)

# %%
g.show()
import networkx as nx
nx.drawing.nx_agraph.write_dot(G, "output.dot")
# Out:
# Graphics object consisting of 278 graphics primitives
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /private/var/tmp/sage-10.1-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages/networkx/drawing/nx_agraph.py:133, in to_agraph(N)
#     132 try:
# --> 133     import pygraphviz
#     134 except ImportError as err:
#
# ModuleNotFoundError: No module named 'pygraphviz'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In [80], line 3
#       1 g.show()
#       2 import networkx as nx
# ----> 3 nx.drawing.nx_agraph.write_dot(G, "output.dot")
#
# File /private/var/tmp/sage-10.1-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages/networkx/drawing/nx_agraph.py:194, in write_dot(G, path)
#     178 def write_dot(G, path):
#     179     """Write NetworkX graph G to Graphviz dot format on path.
#     180
#     181     Parameters
#    (...)
#     192     see https://gitlab.com/graphviz/graphviz/-/issues/1767 for more info.
#     193     """
# --> 194     A = to_agraph(G)
#     195     A.write(path)
#     196     A.clear()
#
# File /private/var/tmp/sage-10.1-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages/networkx/drawing/nx_agraph.py:135, in to_agraph(N)
#     133     import pygraphviz
#     134 except ImportError as err:
# --> 135     raise ImportError(
#     136         "requires pygraphviz " "http://pygraphviz.github.io/"
#     137     ) from err
#     138 directed = N.is_directed()
#     139 strict = nx.number_of_selfloops(N) == 0 and not N.is_multigraph()
#
# ImportError: requires pygraphviz http://pygraphviz.github.io/
